# %% [markdown]
# **INTRODUCTION ABOUT GOOGLE :**

# %% [markdown]
# ### Google LLC is an American multinational technology company focusing on artificial intelligence, online advertising, search engine technology, cloud computing, computer software, quantum computing, e-commerce, and consumer electronics. It has been referred to as "the most powerful company in the world" and as one of the world's most valuable brands due to its market dominance, data collection, and technological advantages in the field of artificial intelligence

# %% [markdown]
# ### my new project is to analyze the google stocks prices from the year of 2013 to 2023

# %% [markdown]
# ##  the above project contains the open prices and close prices and also the high, low and adjusted close,volume of the google stokes

# %% [markdown]
# ## and also the month and years of google stokes exchange will be analysed
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### SAMPLE QUESTION
#
# 1.Which month has high exchange of stokes in open prices?
#
# 2.In which year the google stokes has high growth in trade prices?
#
# 3.What is the percentage of google stokes in close at the month of september?
#
# 4.In which adjusted close values are high satisfied by the share holders?
#
# 5.how many share are having in the year of 2023?

# %% [markdown]
# to call the important python libraries for some analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk

import datetime as dt

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# to get the data from the renewable resources

# %%
google=pd.read_csv('/content/GoogleStock Price.csv')
google.head(3)
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2013-01-02  18.003504  18.193193  17.931683  18.099348  18.099348
# 1  2013-01-03  18.141392  18.316566  18.036036  18.109859  18.109859
# 2  2013-01-04  18.251753  18.555305  18.210211  18.467718  18.467718
#
#       Volume
# 0  101550348
# 1   92635272
# 2  110429460

# %%
google.tail(3)
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 2642  2023-07-03  119.239998  120.190002  118.820000  119.900002  119.900002
# 2643  2023-07-05  119.239998  122.610001  119.230003  121.750000  121.750000
# 2644  2023-07-06  119.800003  120.300003  118.400002  120.110001  120.110001
#
#         Volume
# 2642  14467900
# 2643  27584800
# 2644  24745200

# %% [markdown]
# to calculate the no of columns and null values and shape in the dataset

# %%
google.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %% [markdown]
# there is no any null values in the dataset

# %%
google.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
google.shape
# Out:
# (2645, 7)

# %% [markdown]
# they having 2645 rows and 7 columns

# %% [markdown]
# to find the duplicated values  in the dataset

# %%
google[google.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Date, Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %% [markdown]
# there is no any null values in the dataset

# %% [markdown]
# to convert the date and month and year in the seperate columns

# %%
google['Date'] = pd.to_datetime(google['Date'])

# %%
google.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %%
date=[]
month=[]
year=[]

# %%
for i in google['Date']:
    month.append(i.month)
    date.append(i.day)
    year.append(i.year)

# %%
google['month']=month
google['date']=date
google['year']=year

# %%
google.fillna(0)
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2013-01-02   18.003504   18.193193   17.931683   18.099348   18.099348
# 1    2013-01-03   18.141392   18.316566   18.036036   18.109859   18.109859
# 2    2013-01-04   18.251753   18.555305   18.210211   18.467718   18.467718
# 3    2013-01-07   18.404655   18.503002   18.282784   18.387136   18.387136
# 4    2013-01-08   18.406906   18.425926   18.128880   18.350851   18.350851
# ...         ...         ...         ...         ...         ...         ...
# 2640 2023-06-29  119.239998  120.059998  118.300003  119.099998  119.099998
# 2641 2023-06-30  120.169998  121.080002  119.690002  119.699997  119.699997
# 2642 2023-07-03  119.239998  120.190002  118.820000  119.900002  119.900002
# 2643 2023-07-05  119.239998  122.610001  119.230003  121.750000  121.750000
# 2644 2023-07-06  119.800003  120.300003  118.400002  120.110001  120.110001
#
#          Volume  month  date  year
# ...

# %% [markdown]
# to convert the month and days in text format

# %%
google['month'].value_counts()
# Out:
# 3     241
# 6     234
# 5     233
# 4     227
# 1     223
# 8     221
# 10    221
# 7     215
# 12    211
# 2     210
# 9     205
# 11    204
# Name: month, dtype: int64

# %%
import calendar
google['month'] = google['month'].apply(lambda x: calendar.month_abbr[x])
google.fillna(0)
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2013-01-02   18.003504   18.193193   17.931683   18.099348   18.099348
# 1    2013-01-03   18.141392   18.316566   18.036036   18.109859   18.109859
# 2    2013-01-04   18.251753   18.555305   18.210211   18.467718   18.467718
# 3    2013-01-07   18.404655   18.503002   18.282784   18.387136   18.387136
# 4    2013-01-08   18.406906   18.425926   18.128880   18.350851   18.350851
# ...         ...         ...         ...         ...         ...         ...
# 2640 2023-06-29  119.239998  120.059998  118.300003  119.099998  119.099998
# 2641 2023-06-30  120.169998  121.080002  119.690002  119.699997  119.699997
# 2642 2023-07-03  119.239998  120.190002  118.820000  119.900002  119.900002
# 2643 2023-07-05  119.239998  122.610001  119.230003  121.750000  121.750000
# 2644 2023-07-06  119.800003  120.300003  118.400002  120.110001  120.110001
#
#          Volume month  date  year
# ...

# %%
del google['Date']
google
# Out:
#             Open        High         Low       Close   Adj Close     Volume  \
# 0      18.003504   18.193193   17.931683   18.099348   18.099348  101550348
# 1      18.141392   18.316566   18.036036   18.109859   18.109859   92635272
# 2      18.251753   18.555305   18.210211   18.467718   18.467718  110429460
# 3      18.404655   18.503002   18.282784   18.387136   18.387136   66161772
# 4      18.406906   18.425926   18.128880   18.350851   18.350851   66976956
# ...          ...         ...         ...         ...         ...        ...
# 2640  119.239998  120.059998  118.300003  119.099998  119.099998   24090900
# 2641  120.169998  121.080002  119.690002  119.699997  119.699997   29519700
# 2642  119.239998  120.190002  118.820000  119.900002  119.900002   14467900
# 2643  119.239998  122.610001  119.230003  121.750000  121.750000   27584800
# 2644  119.800003  120.300003  118.400002  120.110001  120.110001   24745200
#
#      month  date  year
# 0      Jan     2  2013
# ...

# %% [markdown]
# ### DATA ANALYSIS

# %% [markdown]
# **1. OPEN STOCK VALUES**

# %% [markdown]
#  open is the starting period of trading on a securities exchange or organized over-the-counter market. An order to buy or sell securities is considered to be open, or in effect, until it is either canceled by the customer, until it is executed, or until it expires.

# %%
google['Open'].value_counts()
# Out:
# 119.239998    3
# 51.700001     2
# 41.924999     2
# 38.500000     2
# 59.400002     2
#              ..
# 36.895500     1
# 37.493500     1
# 37.702499     1
# 37.849998     1
# 119.800003    1
# Name: Open, Length: 2593, dtype: int64

# %%
google=google.round(2)

# %%
google.head(3)
# Out:
#     Open   High    Low  Close  Adj Close     Volume month  date  year
# 0  18.00  18.19  17.93  18.10      18.10  101550348   Jan     2  2013
# 1  18.14  18.32  18.04  18.11      18.11   92635272   Jan     3  2013
# 2  18.25  18.56  18.21  18.47      18.47  110429460   Jan     4  2013

# %%
google['Open']
plt.figure(figsize=(6,3))
plt.title("share holders open rate in google stocks")
sns.histplot(x='Open', data=google, kde=True, color='red')
plt.show()

# %% [markdown]
# more than 890 to 950 share holders have 20 to 40 open price at which the financial security opens in the market when trading begins. It may or may not be different from the previous day's closing price.

# %% [markdown]
# more than 700 to 750 share holders have 40 to 60 open price at which the financial security opens in the market when trading begins. It may or may not be different from the previous day's closing price.

# %% [markdown]
# all other shareholders have between the 40 to 200 open price at which the financial security opens in the market when trading begins. It may or may not be different from the previous day's closing price.

# %% [markdown]
# ## to analyze the stokes exchage between years in 2013 to 2023

# %%
import plotly.express as pl
df = pl.data.tips()
fig = pl.pie(google, values='Open', names='year',title='stock holder having open price of past recent years')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# In last three years the google stock open values are increases rapidly with the percentage of around 48 percentage

# %% [markdown]
# in 2020 the open values of stocks is 18,692.57, in 2021 the open values of stocks is 31,284.66, in 2022 the open values of stocks is 28,834.78

# %% [markdown]
# ## to analyze the stokes exchage between the month januaray to december

# %%
import plotly.express as pl
df = pl.data.tips()
fig = pl.pie(google, values='Open', names='month',title='stock holder having open price of past recent months')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# in open stoks in google they had high open on june and march at the percentage of 9.17% and 9.1%

# %% [markdown]
# In open stokes in google they had least open on setemeber and feburary at the percentage of 7.73% and7.87%

# %% [markdown]
# **2. HIGH STOCK VALUES**

# %% [markdown]
# high is the highest price at which a stock traded during the course of the trading day and is typically higher than the closing or equal to the opening price.

# %%
google['High'].value_counts()
# Out:
# 27.20     6
# 22.27     5
# 27.90     5
# 28.25     5
# 27.49     5
#          ..
# 48.06     1
# 48.09     1
# 48.70     1
# 48.84     1
# 120.30    1
# Name: High, Length: 2181, dtype: int64

# %%
plt.figure(figsize=(6,4))
plt.title('share holders having high stock prices')
sns.histplot(x='High',data=google,kde=True,color='orange')
plt.show()

# %% [markdown]
# most of the stock holder having a high prices ranges from  the 20.00 to 40.00 with the member of above 850 holders

# %% [markdown]
# some least share holder having a high prices ranges from 45.00 to 120.00 with the member of above 880 holders

# %% [markdown]
# ## to analyze the stock exchange between years to 2013 to 2023

# %%
import plotly.express as pl
df = pl.data.tips()
fig = pl.pie(google, values='High', names='year',title='stock prices analysis for high stock price with years')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# In last three years the google stocks has high price values with the percentage of 48.3% of high price

# %% [markdown]
# In 2022 the high prices values is 29,237.44, In 2021 the high prices values is
# 31,564.34, In 2020 the high prices values is 18,932.52

# %% [markdown]
# ## to analyze the stokes exchage between the month januaray to december

# %%
import plotly.express as pl
df = pl.data.tips()
fig = pl.pie(google, values='High', names='month',title='stock holder having high price of past recent months')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# In high stokes values for google shares as high in the month of June and march at the percentage of 9.16% and 9.12%

# %% [markdown]
# In high stokes values ofr google shares as high in the month of september and feburary at the percentage of 7.71% and 7.88%

# %% [markdown]
# **3. LOW STOCK VALUES**

# %% [markdown]
#  low value stocks are called “penny stocks” because they often trade for just a few pennies a share, they are growing in popularity with investors looking to play the stock market without investing large sums in stock. Low value stocks are not traded on the major stock exchanges, like the New York Stock Exchange or NASDAQ.

# %%
google['Low'].value_counts()
# Out:
# 27.25     5
# 29.65     4
# 26.53     4
# 28.45     4
# 29.33     4
#          ..
# 47.35     1
# 48.52     1
# 48.72     1
# 48.67     1
# 118.40    1
# Name: Low, Length: 2186, dtype: int64

# %%
plt.figure(figsize=(5,4))
plt.title('low prices stocks in google')
sns.histplot(x='Low',data=google,kde=True,color='violet')
plt.show()

# %% [markdown]
# more than 1700 share holder having low share values ranges between 20 to 60

# %% [markdown]
# other share holder having the low price values of 50 to 120

# %% [markdown]
# ## to analyze the stokes exchange between the 2013 to 2023

# %%
import plotly.express as pl
df = pl.data.tips()
fig = pl.pie(google, values='Low', names='year',title='stock prices analysis for low stock price with years')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# in last three years the google low price share values has the percentage of 48.2%

# %% [markdown]
# In 2020 the low stock values of google is 18,464, In 2021 the low stock values of google is 31,004.53, In 2022 the low stock values of google is 28,413.48

# %% [markdown]
# the that before decades years ranges from 2013 to 2019 has the low price values of 6000 to 15000

# %% [markdown]
# ## to analyze the stokes exchage between the month januaray to december

# %%
import plotly.express as pl
df = pl.data.tips()
fig = pl.pie(google, values='Low', names='month',title='stock holder having low price of past recent months')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# In low stokes values for google shares as high in the month of June and march at the percentage of 9.17% and 9.08%

# %% [markdown]
# In low stokes values for google shares as least in the month of september and feburaury at the percentage of 7.73% and 7.86%

# %% [markdown]
# **4. CLOSE STOCK VALUES**

# %% [markdown]
#  close is a reference to the end of a trading session in the financial markets when the markets close for the day. The close can also refer to the process of exiting a trade or the final procedure in a financial transaction in which contract documents are signed and recorded.

# %%
google['Close'].value_counts()
# Out:
# 22.22     5
# 38.00     5
# 27.46     5
# 27.88     5
# 27.37     4
#          ..
# 49.30     1
# 48.83     1
# 48.93     1
# 48.76     1
# 121.75    1
# Name: Close, Length: 2171, dtype: int64

# %%
plt.figure(figsize=(5,4))
plt.title('share holders having close stock prices')
sns.histplot(x='Close',data=google,kde=True,color='green')
plt.show()

# %% [markdown]
# most of the share holders having the prices ranges between around 20 to 60
# in 20 to 60 of close price share holders are totally 1650 members

# %% [markdown]
# all other share holder ranges from the 60 to 140 close values having between ranges from  40 to 110 members

# %% [markdown]
# ## to analyze the stokes exchange between the 2013 to 2023

# %%
import plotly.express as pl
df = pl.data.tips()
fig = pl.pie(google, values='Close', names='year',title='stock prices analysis for close stock price with years')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# the year of 2020 and 2021 and 2022 are having more close rates of 18,709.23 and 31,304.73 and 28,804.8

# %% [markdown]
# the percentage of close rate between the 2020 to 2021 has 48.3% of share holders

# %% [markdown]
# ## to analyze the stokes exchage between the month januaray to december

# %%
import plotly.express as pl
df = pl.data.tips()
fig = pl.pie(google, values='Close', names='month',title='stock holder having close price of past recent months')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# In close stokes values for google shares as high in the month of June and march at the percentage of 9.16% and 9.1%
#
# In close stokes values ofr google shares as high in the month of september a d feburary at the percentage of 7.72% and 7.87%

# %% [markdown]
# **5. ADJUSTED CLOSE VALUES**

# %% [markdown]
# Adjusted closing price refers to the price of the stock after paying off the dividends. For instance, if a stock is priced at Rs. 100 and gives a dividend of INR5 per share, then its adjusted closing price would be Rs. 95.

# %%
google['Adj Close'].value_counts()
# Out:
# 22.22     5
# 38.00     5
# 27.46     5
# 27.88     5
# 27.37     4
#          ..
# 49.30     1
# 48.83     1
# 48.93     1
# 48.76     1
# 121.75    1
# Name: Adj Close, Length: 2171, dtype: int64

# %%
plt.figure(figsize=(5,4))
plt.title('share holders having adjusted close stock prices')
sns.histplot(x='Adj Close',data=google,kde=True,color='blue')
plt.show()

# %% [markdown]
# most of the share holder having the adjusted close values of 20 to 60 an average of 1680 share holders

# %% [markdown]
# other share holder having the adjusted close values between the 80 to 120 in holders of above 840 share holders

# %% [markdown]
# ## to analyze the stokes exchange the m

# %%
import plotly.express as pl
df = pl.data.tips()
fig = pl.pie(google, values='Adj Close', names='year',title='stock holder having adjusted close price of past recent years')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# the adjusted close stock values of 2020 and 2021 and 2022 are percentage of11.5% and19.2% and 17.6%

# %% [markdown]
# the year ranges from the 2013 to 2019 has the adjusted close value of percentage of 3.41% to 9.19% per year

# %% [markdown]
# ## to analyze the stokes exchage between the month januaray to december

# %%
import plotly.express as pl
df = pl.data.tips()
fig = pl.pie(google, values='Adj Close', names='month',title='stock prices analysis for adjusted close stock price with months')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# In adjusted close stokes values for google shares as high in the month of June and march at the percentage of 9.16% and 9.1%
#
# In Adjusted close stokes values ofr google shares as high in the month of september a d feburary at the percentage of 7.72% and 7.87%

# %% [markdown]
# **5. VOLUME**

# %% [markdown]
# Volume is an indicator that means the total number of shares that have been bought or sold in a specific period of time or during the trading day. It will also involve the buying and selling of every share during the specific time period.

# %%
google['Volume'].value_counts()
# Out:
# 33210000    3
# 30594000    3
# 34698000    2
# 30326000    2
# 25962000    2
#            ..
# 38246000    1
# 43124000    1
# 42250000    1
# 30984000    1
# 24745200    1
# Name: Volume, Length: 2548, dtype: int64

# %%
plt.figure(figsize=(6,3))
plt.title("Day with highest number of trips")
sns.barplot(x=google['Volume'].value_counts().values,
            y=google['Volume'].value_counts().index)
plt.show()

# %%
plt.figure(figsize=(4,3))
plt.title('share holders having adjusted close stock prices')
sns.histplot(x='Volume',data=google,kde=True,color='black')
plt.show()

# %% [markdown]
# around 300 share holders having 0 to 1 volume that indicated the total number of shares

# %% [markdown]
# ## to analyze the stokes exchange between the years of 2013 to 2023

# %%
import plotly.express as pl
df = pl.data.tips()
fig = pl.pie(google, values='Volume', names='year',title='stock prices analysis for volumes with years')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# In last three years the google stocks has volume price values with the percentage of 17.74% of volume price
#
# In 2022 the volume prices values is 8,727,650,100, In 2021 the volume prices values is 7,689,512,000, In 2020 the volume prices values is 1,010,813,800

# %% [markdown]
# ## to analyze the stokes exchage between the month januaray to december

# %%
import plotly.express as pl
df = pl.data.tips()
fig = pl.pie(google, values='Volume', names='month',title='stock prices analysis for adjusted close stock price with years')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# In volume stokes values for google shares as high in the month of janurary and march at the percentage of 10.1% and 10.2%
#
# In Adjusted close stokes values ofr google shares as high in the month of august and november at the percentage of 6.33% and 6.41%

# %% [markdown]
# **6. STOCKS PURCHASE RESPECT TO MONTH**

# %%
google['month'].value_counts()
# Out:
# Mar    241
# Jun    234
# May    233
# Apr    227
# Jan    223
# Aug    221
# Oct    221
# Jul    215
# Dec    211
# Feb    210
# Sep    205
# Nov    204
# Name: month, dtype: int64

# %% [markdown]
# **stocks vs month**

# %%
plt.figure(figsize=(11,4))
plt.title("google stocks exchange between months")
sns.countplot(x='month',data=google, palette='winter')
plt.show()

# %% [markdown]
# in google stocks the month of March(241),June(234) and May(233) has more number of stocks exchage between last decade years

# %% [markdown]
# **6. DAY TO DAY STOCK EXCHAGE OF GOOGLE**

# %%
google['date'].value_counts()
# Out:
# 8     91
# 13    90
# 9     90
# 11    90
# 6     90
# 22    90
# 23    89
# 10    89
# 14    89
# 12    89
# 24    87
# 21    87
# 28    87
# 3     87
# 27    87
# 17    87
# 16    87
# 15    87
# 7     87
# 5     86
# 18    85
# 19    85
# 20    85
# 2     85
# 26    84
# 1     82
# 4     82
# 29    81
# 30    80
# 25    79
# 31    51
# Name: date, dtype: int64

# %%
plt.figure(figsize=(11,4))
plt.title("Number of stock exchage per each day of a month")
sns.countplot(x='date', data=google, palette='rocket')
plt.show()

# %% [markdown]
# most of the day has above 80 number of stock exchage per day in google stocks

# %% [markdown]
# **7. GOOGLE STOKES VS YEARS**

# %%
google['year'].value_counts()
# Out:
# 2020    253
# 2013    252
# 2014    252
# 2015    252
# 2016    252
# 2019    252
# 2021    252
# 2017    251
# 2018    251
# 2022    251
# 2023    127
# Name: year, dtype: int64

# %%
plt.figure(figsize=(11,4))
plt.title("Number of stock exchage per each day of a month")
sns.countplot(x='year', data=google, palette='rocket')
plt.show()

# %% [markdown]
# from 2013 to 2022 having the google stoks of around 250 to 254
# only 2023 having least number of stokes has 127 stokes

# %% [markdown]
# # Answers
# 1.July month is high exchange of stokes
#
# 2.2020,2021,2022 are exchange of shares
#
# 3.7.72%
#
# 4.20 to 40
#
# 5.127shares in the year of 2023
